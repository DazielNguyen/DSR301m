# %%
print("hello world")
# Out:
# hello world

# %%
# Out:
# The kernel failed to start as '/Users/vananhduy/Library/Python/3.8/lib/python/site-packages/psutil/_psutil_osx.abi3.so' could not be imported from '/Users/vananhduy/Library/Python/3.8/lib/python/site-packages/psutil/_psutil_osx.abi3.so, 0x0002'.
#
# Click <a href='https://aka.ms/kernelFailuresModuleImportErrFromFile'>here</a> for more info.
